# %%
import torchaudio as ta
from chatterbox_infer.mtl_tts import ChatterboxMultilingualTTS
import time
import torch

model = ChatterboxMultilingualTTS.from_pretrained(device="cuda")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import torchaudio as ta
# ----> 2 from chatterbox_infer.mtl_tts import ChatterboxMultilingualTTS
#       3 import time
#       4 import torch
#
# File /workspace/sonussocket/chatterbox_infer/__init__.py:8
#       4     from importlib_metadata import version  # For Python <3.8
#       6 # __version__ = version("chatterbox-tts")
# ----> 8 from .tts import ChatterboxTTS
#       9 from .vc import ChatterboxVC
#      10 from .mtl_tts import ChatterboxMultilingualTTS, SUPPORTED_LANGUAGES
#
# File /workspace/sonussocket/chatterbox_infer/tts.py:4
#       1 from dataclasses import dataclass
#       2 from pathlib import Path
# ----> 4 import librosa
#       5 import torch
#       6 import perth
#
# ModuleNotFoundError: No module named 'librosa'
